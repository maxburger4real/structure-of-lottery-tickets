# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
import torchvision
from torchvision.datasets import MNIST, FashionMNIST
from torch.utils.data import DataLoader
import torch
from PIL import Image
import matplotlib.pyplot as plt
import sys
sys.path.append('../')
from training import datasets

# %%
# fashion mnist variance mean

x,y,xx,yy = datasets.__make_fashion_mnist(scaler=None)
X = np.array(x).reshape(-1, 28, 28)

pixel_means = np.mean(X, axis=0)
pixel_variances = np.var(X, axis=0)
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(pixel_means, cmap='gray')
plt.title('Pixelwise Mean Fashion')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(pixel_variances, cmap='gray')
plt.title('Pixelwise Variance Fashion')
plt.tight_layout()
plt.axis('off')
plt.savefig('fashion_mnist_mean_variance.png', bbox_inches='tight')
plt.show()

# Plot 5 random examples
plt.figure(figsize=(10, 5))

for i in range(5):
    plt.subplot(1, 5, i + 1)
    random_index = np.random.randint(0, len(X))
    plt.imshow(X[random_index], cmap='gray')
    plt.title(f"Label: {y[random_index]}")
    plt.axis('off')

plt.tight_layout()
plt.savefig('fashin_mnist_examples.png', bbox_inches='tight')

# %%
# mnist variance mean
x,y,xx,yy = datasets.__make_mnist(scaler=None)
X = np.array(x).reshape(-1, 28, 28)

pixel_means = np.mean(X, axis=0)
pixel_variances = np.var(X, axis=0)
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(pixel_means, cmap='gray')
plt.title('Pixelwise Mean Fashion')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(pixel_variances, cmap='gray')
plt.title('Pixelwise Variance Fashion')
plt.tight_layout()
plt.axis('off')
plt.savefig('mnist_mean_variance.png', bbox_inches='tight')
plt.show()

# Plot 5 random examples
plt.figure(figsize=(10, 5))

for i in range(5):
    plt.subplot(1, 5, i + 1)
    random_index = np.random.randint(0, len(X))
    plt.imshow(X[random_index], cmap='gray')
    plt.title(f"Label: {y[random_index]}")
    plt.axis('off')

plt.tight_layout()
plt.savefig('mnist_examples.png', bbox_inches='tight')
